# %%
import numpy as np
import pandas as pd

# %%
project_name="odi_data_analysis"

# %%
odi_df=pd.read_csv("data/odi_data.csv") #Read csv data from odi_data.csv in the data directory

# %%
odi_df=odi_df.drop(["BF", "0", "Unnamed: 13", "Unnamed: 0"], axis=1)

# %%
odi_df=odi_df.rename(columns={"Mat":"Matches", "Inns":"Innings", "HS":"Highest", "Ave":"Avg", "100":"Centuries","50":"Fifties"})

# %%
#Show first 10 rows 
odi_df.head(10)
# Out:
#                         Player       Span  Matches Innings  NO   Runs Highest  \
# 0         SR Tendulkar (INDIA)  1989-2012      463     452  41  18426    200*
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015      404     380  41  14234     169
# 2         RT Ponting (AUS/ICC)  1995-2012      375     365  39  13704     164
# 3      ST Jayasuriya (Asia/SL)  1989-2011      445     433  18  13430     189
# 4   DPMD Jayawardene (Asia/SL)  1998-2015      448     418  39  12650     144
# 5    Inzamam-ul-Haq (Asia/PAK)  1991-2007      378     350  53  11739    137*
# 6              V Kohli (INDIA)  2008-2019      242     233  39  11609     183
# 7       JH Kallis (Afr/ICC/SA)  1996-2014      328     314  53  11579     139
# 8      SC Ganguly (Asia/INDIA)  1992-2007      311     300  23  11363     183
# 9    R Dravid (Asia/ICC/INDIA)  1996-2011      344     318  40  10889     153
#
#      Avg     SR Centuries Fifties
# 0  44.83  86.23        49      96
# 1  41.98  78.86        25      93
# ...

# %%
#Show last 10 rows 
odi_df.tail(10)
# Out:
#                     Player       Span  Matches Innings NO Runs Highest Avg SR  \
# 2490    Aamer Hameed (PAK)  1977-1978        2       -  -    -       -   -  -
# 2491      Abdur Rauf (PAK)  2008-2008        4       -  -    -       -   -  -
# 2492     Abu Jayed (BDESH)  2019-2019        2       -  -    -       -   -  -
# 2493      FS Ahangama (SL)  1985-1985        1       -  -    -       -   -  -
# 2494      GW Aldridge (NZ)  2011-2011        2       -  -    -       -   -  -
# 2495       ZS Ansari (ENG)  2015-2015        1       -  -    -       -   -  -
# 2496  Ariful Haque (BDESH)  2018-2018        1       -  -    -       -   -  -
# 2497    Ashfaq Ahmed (PAK)  1994-1994        3       -  -    -       -   -  -
# 2498        MD Bailey (NZ)  1998-1998        1       -  -    -       -   -  -
# 2499        GR Beard (AUS)  1981-1981        2       -  -    -       -   -  -
#
#      Centuries Fifties
# 2490         -       -
# 2491         -       -
# 2492         -       -
# ...

# %%
#odi_df.columns[odi_df.isna().any()]  # DataFrame.isna() detects any missing values
odi_df.dropna() # Dropping rows having at least 1 missing value
odi_df.dropna(axis=1) # Dropping columns having at least 1 missing values
# Out:
#                            Player       Span  Matches Innings  NO   Runs  \
# 0            SR Tendulkar (INDIA)  1989-2012      463     452  41  18426
# 1     KC Sangakkara (Asia/ICC/SL)  2000-2015      404     380  41  14234
# 2            RT Ponting (AUS/ICC)  1995-2012      375     365  39  13704
# 3         ST Jayasuriya (Asia/SL)  1989-2011      445     433  18  13430
# 4      DPMD Jayawardene (Asia/SL)  1998-2015      448     418  39  12650
# ...                           ...        ...      ...     ...  ..    ...
# 2495              ZS Ansari (ENG)  2015-2015        1       -   -      -
# 2496         Ariful Haque (BDESH)  2018-2018        1       -   -      -
# 2497           Ashfaq Ahmed (PAK)  1994-1994        3       -   -      -
# 2498               MD Bailey (NZ)  1998-1998        1       -   -      -
# 2499               GR Beard (AUS)  1981-1981        2       -   -      -
#
#      Highest    Avg     SR Centuries Fifties
# 0       200*  44.83  86.23        49      96
# ...

# %%
odi_df.head()
# Out:
#                         Player       Span  Matches Innings  NO   Runs Highest  \
# 0         SR Tendulkar (INDIA)  1989-2012      463     452  41  18426    200*
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015      404     380  41  14234     169
# 2         RT Ponting (AUS/ICC)  1995-2012      375     365  39  13704     164
# 3      ST Jayasuriya (Asia/SL)  1989-2011      445     433  18  13430     189
# 4   DPMD Jayawardene (Asia/SL)  1998-2015      448     418  39  12650     144
#
#      Avg     SR Centuries Fifties
# 0  44.83  86.23        49      96
# 1  41.98  78.86        25      93
# 2  42.03  80.39        30      82
# 3  32.36   91.2        28      68
# 4  33.37  78.96        19      77

# %%
odi_df.fillna(0)
# Out:
#                            Player       Span  Matches Innings  NO   Runs  \
# 0            SR Tendulkar (INDIA)  1989-2012      463     452  41  18426
# 1     KC Sangakkara (Asia/ICC/SL)  2000-2015      404     380  41  14234
# 2            RT Ponting (AUS/ICC)  1995-2012      375     365  39  13704
# 3         ST Jayasuriya (Asia/SL)  1989-2011      445     433  18  13430
# 4      DPMD Jayawardene (Asia/SL)  1998-2015      448     418  39  12650
# ...                           ...        ...      ...     ...  ..    ...
# 2495              ZS Ansari (ENG)  2015-2015        1       -   -      -
# 2496         Ariful Haque (BDESH)  2018-2018        1       -   -      -
# 2497           Ashfaq Ahmed (PAK)  1994-1994        3       -   -      -
# 2498               MD Bailey (NZ)  1998-1998        1       -   -      -
# 2499               GR Beard (AUS)  1981-1981        2       -   -      -
#
#      Highest    Avg     SR Centuries Fifties
# 0       200*  44.83  86.23        49      96
# ...

# %%
print("Number of rows : {}".format(odi_df.shape[0]))
print("Number of columns :{}".format(odi_df.shape[1]))
# Out:
# Number of rows : 2500
# Number of columns :11

# %%
#Printing all columns
for i in odi_df.columns:
    print(i)
# Out:
# Player
# Span
# Matches
# Innings
# NO
# Runs
# Highest
# Avg
# SR
# Centuries
# Fifties

# %%
description=odi_df.describe()
description
# Out:
#            Matches
# count  2500.000000
# mean     37.161600
# std      58.885075
# min       1.000000
# 25%       4.000000
# 50%      13.000000
# 75%      43.000000
# max     463.000000
